# %% [markdown]
# # CBOE Market Volatility Index (VIX)

# %% [markdown]
# https://www.fidelity.com/learning-center/trading-investing/technical-analysis/technical-indicator-guide/cboe-vix

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

import yfinance as yf
yf.pdr_override()

# %%
# input
symbol = 'AAPL'
index = '^VIX'
start = '2018-01-01'
end = '2019-01-01'

# Read data 
df = yf.download(symbol, start, end)
vix = yf.download(index, start, end)

# View Columns
df.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2018-01-02  42.540001  43.075001  42.314999  43.064999  40.615891  102223600
# 2018-01-03  43.132500  43.637501  42.990002  43.057499  40.608826  118071600
# 2018-01-04  43.134998  43.367500  43.020000  43.257500  40.797443   89738400
# 2018-01-05  43.360001  43.842499  43.262501  43.750000  41.261936   94640000
# 2018-01-08  43.587502  43.902500  43.482498  43.587502  41.108681   82271200

# %%
vix.tail()
# Out:
#                  Open       High    Low      Close  Adj Close  Volume
# Date
# 2018-12-24  29.290001  36.099998  29.16  36.070000  36.070000       0
# 2018-12-26  35.500000  36.200001  29.59  30.410000  30.410000       0
# 2018-12-27  31.200001  33.799999  29.66  29.959999  29.959999       0
# 2018-12-28  29.969999  31.049999  27.43  28.340000  28.340000       0
# 2018-12-31  27.590000  27.639999  25.33  25.420000  25.420000       0

# %%
fig = plt.figure(figsize=(16,10))
ax1 = plt.subplot(2, 1, 1)

ax1.plot(df['Close'], label=symbol)
ax1.set_title(f'{symbol} Closing Price')
ax1.set_ylabel('Price (USD)')
ax1.legend()

# Plot VXN index on second subplot
ax2 = plt.subplot(2, 1, 2)
ax2.plot(vix['Close'], label=index, color='orange')
ax2.set_title(f'{index} Index')
ax2.set_ylabel('Index Value')
ax2.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Candlestick with CBOE Market Volatility Index (VIX)

# %%
from matplotlib import dates as mdates
import datetime as dt

dfc = df.copy()
dfc['VolumePositive'] = dfc['Open'] < dfc['Adj Close']
#dfc = dfc.dropna()
dfc = dfc.reset_index()
dfc['Date'] = pd.to_datetime(dfc['Date'])
dfc['Date'] = dfc['Date'].apply(mdates.date2num)
dfc.head()
# Out:
#        Date       Open       High        Low      Close  Adj Close     Volume  \
# 0  736696.0  42.540001  43.075001  42.314999  43.064999  40.615891  102223600
# 1  736697.0  43.132500  43.637501  42.990002  43.057499  40.608826  118071600
# 2  736698.0  43.134998  43.367500  43.020000  43.257500  40.797443   89738400
# 3  736699.0  43.360001  43.842499  43.262501  43.750000  41.261936   94640000
# 4  736702.0  43.587502  43.902500  43.482498  43.587502  41.108681   82271200
#
#    VolumePositive
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False

# %%
from mplfinance.original_flavor import candlestick_ohlc

fig = plt.figure(figsize=(16,12))
ax1 = plt.subplot(3, 1, 1)
candlestick_ohlc(ax1,dfc.values, width=0.5, colorup='g', colordown='r', alpha=1.0)
ax1.xaxis_date()
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
ax1.grid(True, which='both')
ax1.minorticks_on()
ax1v = ax1.twinx()
colors = dfc.VolumePositive.map({True: 'g', False: 'r'})
ax1v.bar(dfc.Date, dfc['Volume'], color=colors, alpha=0.4)
ax1v.axes.yaxis.set_ticklabels([])
ax1v.set_ylim(0, 3*df.Volume.max())
ax1.set_title('Stock '+ symbol +' Closing Price')
ax1.set_ylabel('Price')

ax2 = plt.subplot(3, 1, 2)
ax2.plot(vix['Close'], label=index, color='orange')
ax2.set_title(f'{index} Index')
ax2.set_ylabel('Index Value')
ax2.legend()
