# 2018-01-04        NaN        NaN        NaN
# 2018-01-05        NaN        NaN        NaN
# 2018-01-08        NaN        NaN        NaN
# 2018-01-09        NaN        NaN        NaN
# 2018-01-10        NaN        NaN        NaN
# 2018-01-11        NaN        NaN        NaN
# 2018-01-12        NaN        NaN        NaN
# 2018-01-16        NaN        NaN        NaN
# 2018-01-17        NaN        NaN        NaN
# 2018-01-18        NaN        NaN        NaN
# 2018-01-19        NaN        NaN        NaN
# 2018-01-22  44.100179  43.576786  43.764821
# 2018-01-23  44.227679  43.711786  43.892321
# 2018-01-24  44.276786  43.733929  43.976607
# 2018-01-25  44.303214  43.706250  44.011786
# 2018-01-26  44.243036  43.652857  43.986071
# 2018-01-29  44.145715  43.530358  43.911250
# 2018-01-30  44.008393  43.374822  43.750178

# %%
fig = plt.figure(figsize=(14,10))
ax1 = plt.subplot(2, 1, 1)
ax1.plot(df['Adj Close'])
ax1.plot(df['MA_High'], label='Moving Average of High')
ax1.plot(df['MA_Low'], label='Moving Average of Low')
ax1.plot(df['MA_Open'], label='Moving Average of Open')
ax1.set_title('Stock '+ symbol +' Closing Price')
ax1.set_ylabel('Price')
ax1.legend(loc='best')

ax2 = plt.subplot(2, 1, 2)
ax2.plot(df['MA_High'], label='Moving Average of High')
ax2.plot(df['MA_Low'], label='Moving Average of Low')
ax2.plot(df['MA_Open'], label='Moving Average of Open')
ax2.grid()
ax2.legend(loc='best')
ax2.set_ylabel('Moving Average of High and Low')
ax2.set_xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# ## Candlestick with Moving Averages of the High and Low

# %%
from matplotlib import dates as mdates
import datetime as dt

dfc = df.copy()
dfc['VolumePositive'] = dfc['Open'] < dfc['Adj Close']
#dfc = dfc.dropna()
dfc = dfc.reset_index()
dfc['Date'] = pd.to_datetime(dfc['Date'])
dfc['Date'] = dfc['Date'].apply(mdates.date2num)
dfc.head()
# Out:
#       Date       Open       High        Low      Close  Adj Close     Volume  \
# 0  17533.0  42.540001  43.075001  42.314999  43.064999  41.135757  102223600
# 1  17534.0  43.132500  43.637501  42.990002  43.057499  41.128586  118071600
# 2  17535.0  43.134998  43.367500  43.020000  43.257500  41.319630   89738400
# 3  17536.0  43.360001  43.842499  43.262501  43.750000  41.790066   94640000
# 4  17539.0  43.587502  43.902500  43.482498  43.587502  41.634842   82271200
#
#    MA_High  MA_Low  MA_Open  VolumePositive
# 0      NaN     NaN      NaN           False
# 1      NaN     NaN      NaN           False
# 2      NaN     NaN      NaN           False
# 3      NaN     NaN      NaN           False
# 4      NaN     NaN      NaN           False

# %%
from mplfinance.original_flavor import candlestick_ohlc

fig = plt.figure(figsize=(14,10))
ax1 = plt.subplot(2, 1, 1)
candlestick_ohlc(ax1,dfc.values, width=0.5, colorup='g', colordown='r', alpha=1.0)
ax1.plot(df['MA_High'], label='Moving Average of High')
ax1.plot(df['MA_Low'], label='Moving Average of Low')
ax1.plot(df['MA_Open'], label='Moving Average of Open')
ax1.xaxis_date()
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
ax1.grid(True, which='both')
ax1.minorticks_on()
ax1v = ax1.twinx()
colors = dfc.VolumePositive.map({True: 'g', False: 'r'})
ax1v.bar(dfc.Date, dfc['Volume'], color=colors, alpha=0.4)
ax1v.axes.yaxis.set_ticklabels([])
ax1v.set_ylim(0, 3*df.Volume.max())
ax1.set_title('Stock '+ symbol +' Closing Price')
ax1.set_ylabel('Price')
ax1.legend(loc='best')

ax2 = plt.subplot(2, 1, 2)
ax2.plot(df['MA_High'], label='Moving Average of High')
ax2.plot(df['MA_Low'], label='Moving Average of Low')
ax2.plot(df['MA_Open'], label='Moving Average of Open')
ax2.grid()
ax2.legend(loc='best')
ax2.set_ylabel('Moving Average of High and Low')
ax2.set_xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')
