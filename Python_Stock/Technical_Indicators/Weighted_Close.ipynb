# %% [markdown]
# # Weighted Close

# %% [markdown]
# https://www.incrediblecharts.com/indicators/weighted_close.php

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

import yfinance as yf
yf.pdr_override()

# %%
# input
symbol = 'AAPL'
start = '2018-09-01'
end = '2019-01-01'

# Read data 
df = yf.download(symbol,start,end)

# View Columns
df.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2018-09-04  57.102501  57.294998  56.657501  57.090000  54.461613  109560400
# 2018-09-05  57.247501  57.417500  56.275002  56.717499  54.106266  133332000
# 2018-09-06  56.557499  56.837502  55.325001  55.775002  53.207165  137160000
# 2018-09-07  55.462502  56.342499  55.177502  55.325001  52.777874  150479200
# 2018-09-10  55.237499  55.462502  54.117500  54.582500  52.069557  158066000

# %%
# Calculate Weighted Close
df['Weighted Close'] = (df['High'] + df['Low'] + df['Close'] * 2) / 4

# %%
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2018-09-04  57.102501  57.294998  56.657501  57.090000  54.461613  109560400
# 2018-09-05  57.247501  57.417500  56.275002  56.717499  54.106266  133332000
# 2018-09-06  56.557499  56.837502  55.325001  55.775002  53.207165  137160000
# 2018-09-07  55.462502  56.342499  55.177502  55.325001  52.777874  150479200
# 2018-09-10  55.237499  55.462502  54.117500  54.582500  52.069557  158066000
#
#             Weighted Close
# Date
# 2018-09-04       57.033125
# 2018-09-05       56.781875
# 2018-09-06       55.928126
# 2018-09-07       55.542500
# 2018-09-10       54.686251

# %%
# Plot the data
plt.figure(figsize=(14, 7))
plt.plot(df['Adj Close'], label='Adj Close', color='blue')
plt.plot(df['Weighted Close'], label='Weighted Close', color='orange')
plt.title('Price and Weighted Close')
plt.legend()
plt.show()

# %% [markdown]
# ## Candlestick with Weighted Close

# %%
from matplotlib import dates as mdates
import datetime as dt

dfc = df.copy()
dfc['VolumePositive'] = dfc['Open'] < dfc['Adj Close']
#dfc = dfc.dropna()
dfc = dfc.reset_index()
dfc['Date'] = pd.to_datetime(dfc['Date'])
dfc['Date'] = dfc['Date'].apply(mdates.date2num)
dfc.head()
# Out:
#        Date       Open       High        Low      Close  Adj Close     Volume  \
# 0  736941.0  57.102501  57.294998  56.657501  57.090000  54.461613  109560400
# 1  736942.0  57.247501  57.417500  56.275002  56.717499  54.106266  133332000
# 2  736943.0  56.557499  56.837502  55.325001  55.775002  53.207165  137160000
# 3  736944.0  55.462502  56.342499  55.177502  55.325001  52.777874  150479200
# 4  736947.0  55.237499  55.462502  54.117500  54.582500  52.069557  158066000
#
#    Weighted Close  VolumePositive
# 0       57.033125           False
# 1       56.781875           False
# 2       55.928126           False
# 3       55.542500           False
# 4       54.686251           False

# %%
from mplfinance.original_flavor import candlestick_ohlc

fig = plt.figure(figsize=(14,10))
ax1 = plt.subplot(2, 1, 1)
candlestick_ohlc(ax1, dfc.values, width=0.5, colorup='g', colordown='r', alpha=1.0)
ax1.plot(df.index, df['Weighted Close'], label='Weighted Close')
ax1.xaxis_date()
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
ax1.grid(True, which='both')
ax1.minorticks_on()
ax1.set_title('Stock ' + symbol + ' Closing Price')
ax1.set_ylabel('Price')
ax1.set_xlabel('Date')

ax1v = ax1.twinx()
colors = dfc.VolumePositive.map({True: 'g', False: 'r'})
ax1v.bar(dfc['Date'], dfc['Volume'], color=colors, alpha=0.4)
ax1v.axes.yaxis.set_ticklabels([])
ax1v.set_ylim(0, 3 * dfc['Volume'].max())
ax1.legend(loc='best')

ax2 = plt.subplot(2, 1, 2)
colors = dfc.VolumePositive.map({True: 'g', False: 'r'})
ax2.bar(dfc.Date, dfc['Volume'], color=colors, alpha=0.4)
ax2.set_ylabel('Volume')
ax2.set_xlabel('Date')
plt.tight_layout()
plt.show()
