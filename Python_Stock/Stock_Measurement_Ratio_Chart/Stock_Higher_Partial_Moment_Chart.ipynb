# %% [markdown]
# # Stock Higher Partial Moment Chart

# %%
# Library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import statistics

import warnings
warnings.filterwarnings("ignore")

from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()

# %%
start = '2019-01-01' #input
end = '2020-07-01' #input
symbol = 'AMD' #input

# %%
stocks = yf.download(symbol, start=start, end=end)['Adj Close']
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
stocks_returns = stocks.pct_change().dropna()

# %%
def hpm(stock_returns, threshold=0.0, order=1):
    threshold_array = np.empty(len(stock_returns))
    threshold_array.fill(threshold)
    diff = stock_returns - threshold_array
    diff = diff.clip()
    return np.sum(diff ** order) / len(stock_returns)

# %%
# Compute the running Higher Partial Moment
running = [hpm(stocks_returns[i-90:i]) for i in range(90, len(stocks_returns))]

# Plot running Higher Partial Moment up to 100 days before the end of the data set
_, ax1 = plt.subplots(figsize=(12,8))
ax1.plot(range(90, len(stocks_returns)-100), running[:-100])
ticks = ax1.get_xticks()
ax1.set_xticklabels([stocks.index[int(i)].date() for i in ticks[:-1]]) # Label x-axis with dates
plt.title(symbol + ' Higher Partial Moment')
plt.xlabel('Date')
plt.ylabel('Higher Partial Moment')
# Out:
# Text(0, 0.5, 'Higher Partial Moment')

# %%
stock_hpm = hpm(stocks_returns)
stock_hpm
# Out:
# 0.003408584638949311

# %%
running = [hpm(stocks_returns[i-90:i]) for i in range(90, len(stocks_returns))]
running
# Out:
# [0.004507735034667003,
#  0.006015385881289499,
#  0.0048503558216744435,
#  0.004105460890558337,
#  0.003805922961622866,
#  0.0037744757988298857,
#  0.004301150743990844,
#  0.00402720287885057,
#  0.0036234944925169223,
#  0.003574829897982037,
#  0.005026030063290372,
#  0.0043660048620562655,
#  0.004056949224463502,
#  0.004351489792278877,
#  0.00439791065397743,
#  0.004610392471965412,
#  0.004008550134551927,
#  0.005769032556177431,
#  0.0064871108885591715,
#  0.004551780848248794,
#  0.0036424021846202647,
#  0.003518032647048752,
#  0.003417526887208949,
#  0.003430522701608939,
#  0.003029820552888275,
#  0.003787305648354111,
#  0.0036193035067675215,
#  0.003484181237850497,
#  0.0032150069529600683,
#  0.0032614915094057967,
#  0.002973443703441498,
#  0.0031173361995684803,
#  0.00329516242880593,
#  0.003161424651519846,
#  0.003479005057592492,
#  0.0032888644838588665,
#  0.0031114395855589023,
#  0.0034467039108982893,
#  0.003972211664773538,
#  0.004333486021929711,
#  0.004477167582826411,
#  0.004382580724689004,
#  0.00437118610875121,
#  0.005281346795540993,
#  0.005270494570148563,
#  0.005223658473920866,
#  0.0045456668649022855,
#  0.004124198084556551,
#  0.004292433590586369,
#  0.004775041018033174,
#  0.004751895839296255,
#  0.0046276513974227666,
#  0.003428934831265208,
#  0.0033807724937514223,
#  0.002563381111881301,
#  0.002046997859292659,
#  0.0020002509587744915,
#  0.0019637618756687594,
#  0.0017625154655615107,
#  0.002031987735003403,
#  0.0019550824333345045,
#  0.003389819602840902,
#  0.003313872924226187,
#  0.001799019332645234,
#  0.00166258026341478,
#  0.0010575142062007727,
#  0.0010206110358244888,
#  0.0020884861383021827,
#  0.0019547327761654516,
#  0.0017024543544340576,
#  0.002032921674850464,
#  0.0023104837016498236,
#  0.0012445385651506386,
#  0.0016979214420267841,
#  0.0015917700081256615,
#  0.0016044556901912027,
#  0.001929116936949973,
#  0.0017344640218634356,
#  0.0018524805704043948,
#  0.0017820856929040747,
#  0.002055257300546709,
#  0.0017477640782710894,
#  0.002055703443469031,
#  0.0013439722040152597,
#  0.0011987164506928555,
#  0.0016817119140098708,
#  0.0021662211382282746,
#  0.00203769539081583,
#  0.0020461410120585343,
#  0.0015355141561057526,
#  0.0021715469656167032,
#  0.0016261914514432239,
#  0.0017386037074219917,
#  0.0011592202656752772,
#  0.0013690570793283483,
#  0.0016740398383336555,
#  0.0011122392081549897,
#  0.0011923210487021546,
#  0.0015298033264691234,
#  0.001322229366735465,
#  0.0003706249008040939,
#  0.0008656550599266301,
#  0.0008587473412009322,
#  0.0008356676227960966,
#  0.0008572812455306513,
#  2.4340282692068993e-05,
#  0.0005870149139830243,
#  4.508836469811298e-06,
#  -0.00013236295101657234,
#  -0.000380931075979813,
#  1.2261081641062876e-05,
#  3.045377099091251e-05,
#  0.0006835214629348255,
#  0.0008677239547598901,
#  0.00123936597102534,
#  0.0008912696620853391,
#  0.0012198093856159553,
#  0.001731207273530677,
#  0.0018504610635674816,
#  0.0018230093263142486,
#  0.0022432071213804652,
#  0.002149479353052318,
#  0.002290809888904208,
#  0.002381683275597071,
#  0.0020104012130683913,
#  0.002104391228188707,
#  0.002125237679331894,
#  0.0020209272667044273,
#  0.001952852814569771,
#  0.0018130823436130544,
#  0.0018443636472886482,
#  0.002145252165004675,
#  0.002475199057791444,
#  0.002473250022646044,
#  0.002564298485703144,
#  0.00225050305748225,
#  0.0023448894709549163,
#  0.002691510597049566,
#  0.0023519121495732824,
#  0.002255127157886975,
#  0.0019761246701810982,
#  0.002000252389336594,
#  0.0019335227735841805,
#  0.0023355388906504547,
#  0.002186512354527961,
#  0.003311253625400701,
#  0.003330282799836374,
#  0.003632127637422892,
#  0.004187832718503418,
#  0.004720774813356453,
#  0.004218050036894586,
#  0.002741603564663581,
#  0.002763353375586107,
#  0.0032132195270640003,
#  0.0034620751892437134,
#  0.004451595687738414,
#  0.0049907147350222196,
#  0.004689203893282359,
#  0.004603784958794756,
#  0.004764805674678574,
#  0.004251550258855997,
#  0.004264440653892824,
#  0.005871450739201127,
#  0.005479961074910512,
#  0.005461305923738549,
#  0.005215767677418115,
#  0.004877189803276839,
#  0.005142016468551155,
#  0.0051548111106946865,
#  0.0052706174180556006,
#  0.004950089479094577,
#  0.005360020243909326,
#  0.005661043489984006,
#  0.006018373311377767,
#  0.006217302212251737,
#  0.0061319997069983105,
#  0.006015949067345612,
#  0.005673035056879617,
#  0.005374832726124406,
#  0.005865661589054692,
#  0.005249072598058243,
#  0.005634124679162943,
#  0.005010521459206828,
#  0.005657806215555668,
#  0.005981158909356481,
#  0.006095119623169706,
#  0.006261966449558796,
#  0.006249876718125415,
#  0.006903303984419549,
#  0.007404579771458054,
#  0.007277949201502698,
#  0.0072820576374307755,
#  0.007471632835459452,
#  0.008057883817777918,
#  0.008359928642598685,
#  0.008083672186797269,
#  0.0067731891198059965,
#  0.005614338147822388,
#  0.005194574798291105,
#  0.005143337209090759,
#  0.0042101209985236044,
#  0.004641907083733637,
#  0.004745339927504684,
#  0.00475950423828239,
#  0.005610971484889488,
#  0.005039952118846584,
#  0.00480402478488189,
#  0.003254604941547767,
#  0.004014093500419855,
#  0.0040588039177144606,
#  0.0021639503353801702,
#  0.0032423841460713777,
#  0.0014829459105470215,
#  0.002435710716943239,
#  0.0017710791523910295,
#  0.0018616631490623006,
#  0.0018000031302735702,
#  0.002363320065888054,
#  0.0034630339983618605,
#  0.0028356388298734956,
#  0.0033043611939150013,
#  0.003028312989783968,
#  0.00295328211958521,
#  0.0020078992358050947,
#  0.0016466805736521076,
#  0.0022537660315422726,
#  0.0018832778341901384,
#  0.002987805758067933,
#  0.0032205535872053535,
#  0.0033882215116607804,
#  0.003368153841700682,
#  0.00407529156854837,
#  0.004896825630690127,
#  0.0046833135897967485,
#  0.0050989412255628315,
#  0.005027849740116626,
#  0.005296744809837801,
#  0.004361294888710641,
#  0.004982724105163442,
#  0.004100446971597622,
#  0.004531776348289913,
#  0.004269070500484489,
#  0.003966118670483343,
#  0.0037179157536371614,
#  0.003315725116801744,
#  0.002440954165948566,
#  0.0027082590169591396,
#  0.0023660721748312067,
#  0.002338198585956978,
#  0.002400691915873867,
#  0.0028247025969231937,
#  0.003274393190309868,
#  0.00209470561117284,
#  0.0018812995526573512,
#  0.0024254557135202576,
#  0.0023944130677136877,
#  0.0025710817994520044,
#  0.0024853683347344623,
#  0.0028511694774246608,
#  0.002374533644167498,
#  0.00260333338006891,
#  0.0021262051014192393,
#  0.001752994673272718,
#  0.0012833485648326142,
#  0.001699551390012894,
#  0.0015817344899053966,
#  0.0015025962958570382,
#  0.0016267255560080745,
#  0.0018461926643480971,
#  0.0016589553429444952,
#  0.002295825638453677,
#  0.002716198826352192,
#  0.003328539384310547,
#  0.002195653343208152,
#  0.0020056854358549204,
#  0.002163122531830344,
#  0.002234344362540519,
#  0.002160339221930173,
#  0.0014911848920600244,
#  0.0012028274010273201,
#  0.0012928307402658922,
#  0.001004638180423313,
#  0.0005164241827383274,
#  0.00010146295473927437,
#  -0.0006826610450232239,
#  -0.0003352514699280107]
