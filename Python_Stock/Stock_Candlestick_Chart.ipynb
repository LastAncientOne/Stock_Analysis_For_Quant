# %% [markdown]
# # Stock Interactive Candlestick Chart

# %%
# Library
import pandas as pd
import numpy as np
import plotly  
import plotly.graph_objs as go

import warnings
warnings.filterwarnings("ignore")

from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()

# %%
plotly.__version__
# Out:
# '4.11.0'

# %%
start = '2016-01-01' #input
end = '2020-07-01' #input
symbol = 'AMD'

# %%
df = yf.download("AMD", start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
#             Adj Close  Close  High   Low  Open    Volume
# Date
# 2016-01-04       2.77   2.77  2.82  2.63  2.77  32516800
# 2016-01-05       2.75   2.75  2.80  2.64  2.77  12972300
# 2016-01-06       2.51   2.51  2.71  2.47  2.66  23759400
# 2016-01-07       2.28   2.28  2.48  2.26  2.43  22203500
# 2016-01-08       2.14   2.14  2.42  2.10  2.36  31822400

# %%
df.tail()
# Out:
#             Adj Close      Close       High        Low       Open    Volume
# Date
# 2020-06-24  52.389999  52.389999  54.740002  51.919998  53.939999  53535500
# 2020-06-25  51.930000  51.930000  52.700001  50.540001  52.560001  51129600
# 2020-06-26  50.099998  50.099998  51.950001  49.450001  51.849998  65485700
# 2020-06-29  50.279999  50.279999  50.279999  48.419998  50.150002  49905800
# 2020-06-30  52.610001  52.610001  52.770000  50.820000  51.160000  42275700

# %%
fig = go.Figure(data=[go.Candlestick(x=df.index,
                       open=df['Open'],
                       high=df['High'],
                       low=df['Low'],
                       close=df['Close'])])

# %%
fig.show()

# %%
fig = go.Figure(data=[go.Candlestick(x=df.index,
open=df['Open'],
high=df['High'],
low=df['Low'],
close=df['Close'],
increasing_line_color='red',
decreasing_line_color = 'blue'
)])
fig.show()
