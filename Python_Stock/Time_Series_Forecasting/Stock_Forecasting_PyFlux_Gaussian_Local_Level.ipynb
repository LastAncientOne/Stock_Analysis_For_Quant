# %% [markdown]
# # Stock Forecasting using PyFlux

# %% [markdown]
# ### Gaussian Local Level models

# %% [markdown]
# https://github.com/RJT1990/pyflux

# %%
# Data manipulation
# ==============================================================================
import pandas as pd
import numpy as np
import datetime

# Plots
# ==============================================================================
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# Modelling and Forecasting
# ==============================================================================
import pyflux as pf

# Warnings configuration
# ==============================================================================
import warnings
warnings.filterwarnings("ignore")

# Yahoo finance is used to fetch data 
# ==============================================================================
import yfinance as yf
yf.pdr_override()

# %%
symbol = '^GSPC' # input
start = '2020-01-01' # input 
end = '2022-07-18'  # input
df = yf.download(symbol, start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-01-02  3244.669922  3258.139893  3235.530029  3257.850098  3257.850098
# 2020-01-03  3226.360107  3246.149902  3222.340088  3234.850098  3234.850098
# 2020-01-06  3217.550049  3246.840088  3214.639893  3246.280029  3246.280029
# 2020-01-07  3241.860107  3244.909912  3232.429932  3237.179932  3237.179932
# 2020-01-08  3238.590088  3267.070068  3236.669922  3253.050049  3253.050049
#
#                 Volume
# Date
# 2020-01-02  3458250000
# 2020-01-03  3461290000
# 2020-01-06  3674070000
# 2020-01-07  3420380000
# 2020-01-08  3720890000

# %%
df.tail()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2022-07-11  3880.939941  3880.939941  3847.219971  3854.429932  3854.429932
# 2022-07-12  3851.949951  3873.409912  3802.360107  3818.800049  3818.800049
# 2022-07-13  3779.669922  3829.439941  3759.070068  3801.780029  3801.780029
# 2022-07-14  3763.989990  3796.409912  3721.560059  3790.379883  3790.379883
# 2022-07-15  3818.000000  3863.620117  3817.179932  3863.159912  3863.159912
#
#                 Volume
# Date
# 2022-07-11  3023830000
# 2022-07-12  3138460000
# 2022-07-13  3166580000
# 2022-07-14  3447500000
# 2022-07-15  3537130000

# %%
returns = pd.DataFrame(np.diff(np.log(df['Adj Close'].values)))
returns.index = df.index.values[1:df.index.values.shape[0]]
returns.columns = [symbol + " Returns"]

returns.head()
# Out:
#             ^GSPC Returns
# 2020-01-03      -0.007085
# 2020-01-06       0.003527
# 2020-01-07      -0.002807
# 2020-01-08       0.004890
# 2020-01-09       0.006633

# %%
plt.figure(figsize=(15, 5))
plt.plot(returns.index, np.abs(returns))
plt.ylabel('Absolute Returns')
plt.title(symbol + ' Absolute Returns')
plt.show()

# %%
returns
# Out:
#             ^GSPC Returns
# 2020-01-03      -0.007085
# 2020-01-06       0.003527
# 2020-01-07      -0.002807
# 2020-01-08       0.004890
# 2020-01-09       0.006633
# ...                   ...
# 2022-07-11      -0.011594
# 2022-07-12      -0.009287
# 2022-07-13      -0.004467
# 2022-07-14      -0.003003
# 2022-07-15       0.019019
#
# [638 rows x 1 columns]

# %%
model = pf.LLEV(data=df, target='Adj Close')
x = model.fit()
x.summary()
# Out:
# LLEV
# ======================================================= ==================================================
# Dependent Variable: Adj Close                           Method: MLE
# Start Date: 2020-01-02 00:00:00                         Log Likelihood: -3444.7667
# End Date: 2022-07-15 00:00:00                           AIC: 6893.5333
# Number of observations: 639                             BIC: 6902.4532
# ==========================================================================================================
# Latent Variable                          Estimate   Std Error  z        P>|z|    95% C.I.
# ======================================== ========== ========== ======== ======== =========================
# Sigma^2 irregular                        365.426093
# Sigma^2 level                            2103.71322
# ==========================================================================================================

# %%
model.plot_fit(figsize=(15,10))

# %%
model.plot_predict_is(h=20,figsize=(25,5))

# %%
model.plot_predict(h=5,figsize=(25,5))
