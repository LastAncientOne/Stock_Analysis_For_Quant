# %% [markdown]
# # Stock Forecasting using PyFlux

# %% [markdown]
# ### Beta-t-EGARCH in-mean regression models

# %% [markdown]
# https://github.com/RJT1990/pyflux

# %%
# Data manipulation
# ==============================================================================
import pandas as pd
import numpy as np
import datetime

# Plots
# ==============================================================================
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# Modelling and Forecasting
# ==============================================================================
import pyflux as pf

# Warnings configuration
# ==============================================================================
import warnings
warnings.filterwarnings("ignore")

# Yahoo finance is used to fetch data 
# ==============================================================================
import yfinance as yf
yf.pdr_override()

# %%
symbol = 'AMD' # input
market = '^GSPC'
start = '2020-01-01' # input 
end = '2022-07-18'  # input
df = yf.download(symbol, start, end)
df2 = yf.download(market, start, end)
one_mon = yf.download('^IRX', start, end)['Adj Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
log_returns = pd.DataFrame(np.diff(np.log(df['Adj Close'].values)))
log_returns.index = df.index.values[1:df.index.values.shape[0]]
log_returns.columns = [symbol + " Returns"]

log_returns.head()
# Out:
#             AMD Returns
# 2020-01-03    -0.010236
# 2020-01-06    -0.004330
# 2020-01-07    -0.002897
# 2020-01-08    -0.008743
# 2020-01-09     0.023555

# %%
market_returns = pd.DataFrame(np.diff(np.log(df2['Adj Close'].values)))
market_returns.index = df2.index.values[1:df2.index.values.shape[0]]
market_returns.columns = [market + " Returns"]

market_returns.head()
# Out:
#             ^GSPC Returns
# 2020-01-03      -0.007085
# 2020-01-06       0.003527
# 2020-01-07      -0.002807
# 2020-01-08       0.004890
# 2020-01-09       0.006633

# %%
one_day = pd.DataFrame(np.log(1+one_mon)/365)
one_day.columns = ["US Treasury Returns"]
one_day
# Out:
#             US Treasury Returns
# Date
# 2020-01-02             0.002505
# 2020-01-03             0.002481
# 2020-01-06             0.002497
# 2020-01-07             0.002510
# 2020-01-08             0.002503
# ...                         ...
# 2022-07-12             0.003111
# 2022-07-13             0.003290
# 2022-07-14             0.003249
# 2022-07-15             0.003221
# 2022-07-18             0.003238
#
# [519 rows x 1 columns]

# %%
returns = pd.concat([one_day,log_returns,market_returns],axis=1).dropna()
returns.head()
# Out:
#             US Treasury Returns  AMD Returns  ^GSPC Returns
# 2020-01-03             0.002481    -0.010236      -0.007085
# 2020-01-06             0.002497    -0.004330       0.003527
# 2020-01-07             0.002510    -0.002897      -0.002807
# 2020-01-08             0.002503    -0.008743       0.004890
# 2020-01-09             0.002510     0.023555       0.006633

# %%
excess_stock = returns["AMD Returns"].values - returns['US Treasury Returns'].values
excess_market = returns["^GSPC Returns"].values - returns['US Treasury Returns'].values

# %%
final_returns = pd.DataFrame(np.transpose([excess_stock,excess_market, returns['US Treasury Returns'].values]))
final_returns.columns=["AMD","SP500","Rf"]
final_returns.index = returns.index

# %%
plt.figure(figsize=(15,5))
plt.title("Excess Returns")
x = plt.plot(final_returns);
plt.legend(iter(x), final_returns.columns)

# %%
modelx = pf.EGARCHMReg(p=1,q=1,data=final_returns,formula='AMD ~ Rf')
results = modelx.fit()
results.summary()
# Out:
# EGARCHMReg(1,1)
# ======================================================= ==================================================
# Dependent Variable: AMD                                 Method: MLE
# Start Date: 2020-01-06 00:00:00                         Log Likelihood: 1015.4943
# End Date: 2022-07-15 00:00:00                           AIC: -2014.9885
# Number of observations: 516                             BIC: -1981.0197
# ==========================================================================================================
# Latent Variable                          Estimate   Std Error  z        P>|z|    95% C.I.
# ======================================== ========== ========== ======== ======== =========================
# p(1)                                     0.9664
# q(1)                                     0.0898
# v                                        10.8076
# GARCH-M                                  -0.026     0.0018     -14.3984 0.0      (-0.0295 | -0.0224)
# Vol Beta 1                               -0.2502    0.1181     -2.1184  0.0341   (-0.4818 | -0.0187)
# Vol Beta Rf                              22.552     10.6175    2.124    0.0337   (1.7418 | 43.3623)
# Returns Beta 1                           0.002      0.0011     1.8469   0.0648   (-0.0001 | 0.0041)
# Returns Beta Rf                          -2.0106    1.4008     -1.4353  0.1512   (-4.7562 | 0.7349)
# ==========================================================================================================

# %%
modelx.plot_z([5,7],figsize=(15,5))

# %%
modelx.plot_fit(figsize=(15,5))
