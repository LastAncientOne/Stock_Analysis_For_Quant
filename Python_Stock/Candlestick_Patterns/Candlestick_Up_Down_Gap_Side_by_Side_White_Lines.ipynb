# %% [markdown]
# # Candlestick Up/Down-gap side-by-side white lines

# %% [markdown]
# https://www.investopedia.com/terms/u/updown-gap-sidebyside-white-lines.asp

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import talib

import warnings
warnings.filterwarnings("ignore")

# yahoo finance is used to fetch data 
import yfinance as yf
yf.pdr_override()

# %%
# input
symbol = 'AAPL'
start = '2018-01-01'
end = '2021-10-11'

# Read data 
df = yf.download(symbol,start,end)

# View Columns
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2018-01-02  42.540001  43.075001  42.314999  43.064999  41.248272  102223600
# 2018-01-03  43.132500  43.637501  42.990002  43.057499  41.241089  118071600
# 2018-01-04  43.134998  43.367500  43.020000  43.257500  41.432652   89738400
# 2018-01-05  43.360001  43.842499  43.262501  43.750000  41.904377   94640000
# 2018-01-08  43.587502  43.902500  43.482498  43.587502  41.748741   82271200

# %% [markdown]
# ## Candlestick with Up/Down-gap side-by-side white lines

# %%
from matplotlib import dates as mdates
import datetime as dt

dfc = df.copy()
dfc['VolumePositive'] = dfc['Open'] < dfc['Adj Close']
#dfc = dfc.dropna()
dfc = dfc.reset_index()
dfc['Date'] = pd.to_datetime(dfc['Date'])
dfc['Date'] = dfc['Date'].apply(mdates.date2num)
dfc.head()
# Out:
#        Date       Open       High        Low      Close  Adj Close     Volume  \
# 0  736696.0  42.540001  43.075001  42.314999  43.064999  41.248272  102223600
# 1  736697.0  43.132500  43.637501  42.990002  43.057499  41.241089  118071600
# 2  736698.0  43.134998  43.367500  43.020000  43.257500  41.432652   89738400
# 3  736699.0  43.360001  43.842499  43.262501  43.750000  41.904377   94640000
# 4  736702.0  43.587502  43.902500  43.482498  43.587502  41.748741   82271200
#
#    VolumePositive
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False

# %%
from mplfinance.original_flavor import candlestick_ohlc

fig = plt.figure(figsize=(14,10))
ax = plt.subplot(2, 1, 1)
candlestick_ohlc(ax,dfc.values, width=0.5, colorup='g', colordown='r', alpha=1.0)
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
ax.grid(True, which='both')
ax.minorticks_on()
axv = ax.twinx()
colors = dfc.VolumePositive.map({True: 'g', False: 'r'})
axv.bar(dfc.Date, dfc['Volume'], color=colors, alpha=0.4)
axv.axes.yaxis.set_ticklabels([])
axv.set_ylim(0, 3*df.Volume.max())
ax.set_title('Stock '+ symbol +' Closing Price')
ax.set_ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
gap_side_by_side_white_lines = talib.CDLGAPSIDESIDEWHITE(df['Open'], df['High'], df['Low'], df['Close'])

gap_side_by_side_white_lines = gap_side_by_side_white_lines[gap_side_by_side_white_lines != 0]

# %%
df['gap_side_by_side_white_lines'] = talib.CDLGAPSIDESIDEWHITE(df['Open'], df['High'], df['Low'], df['Close'])

# %%
df.loc[df['gap_side_by_side_white_lines'] !=0]
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2019-07-05  50.837502  51.270000  50.724998  51.057499  50.042671  69062000
# 2019-11-05  64.262497  64.547501  64.080002  64.282501  63.244194  79897600
# 2019-11-06  64.192497  64.372498  63.842499  64.309998  63.271248  75864400
# 2019-11-08  64.672501  65.110001  64.212502  65.035004  64.176636  69986400
#
#             gap_side_by_side_white_lines
# Date
# 2019-07-05                           100
# 2019-11-05                           100
# 2019-11-06                          -100
# 2019-11-08                           100

# %%
df['Adj Close'].loc[df['gap_side_by_side_white_lines'] !=0]
# Out:
# Date
# 2019-07-05    50.042671
# 2019-11-05    63.244194
# 2019-11-06    63.271248
# 2019-11-08    64.176636
# Name: Adj Close, dtype: float64

# %%
df['Adj Close'].loc[df['gap_side_by_side_white_lines'] !=0].index
# Out:
# DatetimeIndex(['2019-07-05', '2019-11-05', '2019-11-06', '2019-11-08'], dtype='datetime64[ns]', name='Date', freq=None)

# %%
gap_side_by_side_white_lines
# Out:
# Date
# 2019-07-05    100
# 2019-11-05    100
# 2019-11-06   -100
# 2019-11-08    100
# dtype: int32

# %%
gap_side_by_side_white_lines.index
# Out:
# DatetimeIndex(['2019-07-05', '2019-11-05', '2019-11-06', '2019-11-08'], dtype='datetime64[ns]', name='Date', freq=None)

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-01-02   42.540001   43.075001   42.314999   43.064999   41.248272
# 2018-01-03   43.132500   43.637501   42.990002   43.057499   41.241089
# 2018-01-04   43.134998   43.367500   43.020000   43.257500   41.432652
# 2018-01-05   43.360001   43.842499   43.262501   43.750000   41.904377
# 2018-01-08   43.587502   43.902500   43.482498   43.587502   41.748741
# ...                ...         ...         ...         ...         ...
# 2021-10-04  141.759995  142.210007  138.270004  139.139999  139.139999
# 2021-10-05  139.490005  142.240005  139.360001  141.110001  141.110001
# 2021-10-06  139.470001  142.149994  138.369995  142.000000  142.000000
# 2021-10-07  143.059998  144.220001  142.720001  143.289993  143.289993
# 2021-10-08  144.029999  144.179993  142.559998  142.899994  142.899994
#
#                Volume  gap_side_by_side_white_lines
# Date
# 2018-01-02  102223600                             0
# 2018-01-03  118071600                             0
# 2018-01-04   89738400                             0
# 2018-01-05   94640000                             0
# 2018-01-08   82271200                             0
# ...               ...                           ...
# 2021-10-04   98322000                             0
# 2021-10-05   80861100                             0
# 2021-10-06   83221100                             0
# 2021-10-07   61732700                             0
# 2021-10-08   58718700                             0
#
# [950 rows x 7 columns]

# %%
fig = plt.figure(figsize=(20,16))
ax = plt.subplot(2, 1, 1)
candlestick_ohlc(ax,dfc.values, width=0.5, colorup='g', colordown='r', alpha=1.0)
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
ax.grid(True, which='both')
ax.minorticks_on()
axv = ax.twinx()
ax.plot_date(df['Adj Close'].loc[df['gap_side_by_side_white_lines'] !=0].index, df['Adj Close'].loc[df['gap_side_by_side_white_lines'] !=0],
                'or', # marker style 'o', color 'g'
                fillstyle='none', # circle is not filled (with color)
                ms=10.0) 
colors = dfc.VolumePositive.map({True: 'g', False: 'r'})
axv.bar(dfc.Date, dfc['Volume'], color=colors, alpha=0.4)
axv.axes.yaxis.set_ticklabels([])
axv.set_ylim(0, 3*df.Volume.max())
ax.set_title('Stock '+ symbol +' Closing Price')
ax.set_ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# ## Plot Certain dates

# %%
df = df['2019-11-01':'2019-12-01']
dfc = df.copy()
dfc['VolumePositive'] = dfc['Open'] < dfc['Adj Close']
#dfc = dfc.dropna()
dfc = dfc.reset_index()
dfc['Date'] = pd.to_datetime(dfc['Date'])
dfc['Date'] = dfc['Date'].apply(mdates.date2num)
dfc.head()
# Out:
#        Date       Open       High        Low      Close  Adj Close     Volume  \
# 0  737364.0  62.384998  63.982498  62.290001  63.955002  62.921974  151125200
# 1  737367.0  64.332497  64.462502  63.845001  64.375000  63.335197  103272000
# 2  737368.0  64.262497  64.547501  64.080002  64.282501  63.244194   79897600
# 3  737369.0  64.192497  64.372498  63.842499  64.309998  63.271248   75864400
# 4  737370.0  64.684998  65.087502  64.527496  64.857498  64.001472   94940400
#
#    gap_side_by_side_white_lines  VolumePositive
# 0                             0            True
# 1                             0           False
# 2                           100           False
# 3                          -100           False
# 4                             0           False

# %%
fig = plt.figure(figsize=(20,16))
ax = plt.subplot(2, 1, 1)
#ax.set_facecolor('lightyellow')
candlestick_ohlc(ax,dfc.values, width=0.5, colorup='g', colordown='r', alpha=1.0)
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
#ax.grid(True, which='both')
#ax.minorticks_on()
axv = ax.twinx()
ax.plot_date(df['Adj Close'].loc[df['gap_side_by_side_white_lines'] !=0].index, df['Adj Close'].loc[df['gap_side_by_side_white_lines'] !=0],
                '3', # marker style 'o', color 'g'
                fillstyle='none', # circle is not filled (with color)
                ms=30.0) 
colors = dfc.VolumePositive.map({True: 'g', False: 'r'})
axv.bar(dfc.Date, dfc['Volume'], color=colors, alpha=0.4)
axv.axes.yaxis.set_ticklabels([])
axv.set_ylim(0, 3*df.Volume.max())
ax.set_title('Stock '+ symbol +' Closing Price')
ax.set_ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# # Highlight Candlestick

# %%
from matplotlib.dates import date2num
from datetime import datetime

fig = plt.figure(figsize=(20,16))
ax = plt.subplot(2, 1, 1)
candlestick_ohlc(ax,dfc.values, width=0.5, colorup='g', colordown='r', alpha=1.0)
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
#ax.grid(True, which='both')
#ax.minorticks_on()
axv = ax.twinx()
ax.axvspan(date2num(datetime(2019,11,4)), date2num(datetime(2019,11,5)), 
           label="Up Gap Side-by-Side White Lines",color="green", alpha=0.3)
ax.axvspan(date2num(datetime(2019,11,6)), date2num(datetime(2019,11,7)), 
           label="Down Gap Side-by-Side White Lines",color="red", alpha=0.3)
ax.axvspan(date2num(datetime(2019,11,8)), date2num(datetime(2019,11,9)), 
           label="Up Gap Side-by-Side White Lines",color="green", alpha=0.3)
ax.legend(loc='upper center')
colors = dfc.VolumePositive.map({True: 'g', False: 'r'})
axv.bar(dfc.Date, dfc['Volume'], color=colors, alpha=0.4)
axv.axes.yaxis.set_ticklabels([])
axv.set_ylim(0, 3*df.Volume.max())
ax.set_title('Stock '+ symbol +' Closing Price')
ax.set_ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')
