# %% [markdown]
# # Candlestick In-Neck

# %% [markdown]
# https://www.investopedia.com/terms/n/neck-pattern.asp

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import talib

import warnings
warnings.filterwarnings("ignore")

# yahoo finance is used to fetch data 
import yfinance as yf
yf.pdr_override()

# %%
# input
symbol = 'AMD'
start = '2016-01-01'
end = '2021-10-08'

# Read data 
df = yf.download(symbol,start,end)

# View Columns
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#             Open  High   Low  Close  Adj Close    Volume
# Date
# 2016-01-04  2.77  2.82  2.63   2.77       2.77  32516800
# 2016-01-05  2.77  2.80  2.64   2.75       2.75  12972300
# 2016-01-06  2.66  2.71  2.47   2.51       2.51  23759400
# 2016-01-07  2.43  2.48  2.26   2.28       2.28  22203500
# 2016-01-08  2.36  2.42  2.10   2.14       2.14  31822400

# %% [markdown]
# ## Candlestick with In-Neck

# %%
from matplotlib import dates as mdates
import datetime as dt

dfc = df.copy()
dfc['VolumePositive'] = dfc['Open'] < dfc['Adj Close']
#dfc = dfc.dropna()
dfc = dfc.reset_index()
dfc['Date'] = pd.to_datetime(dfc['Date'])
dfc['Date'] = dfc['Date'].apply(mdates.date2num)
dfc.head()
# Out:
#        Date  Open  High   Low  Close  Adj Close    Volume  VolumePositive
# 0  735967.0  2.77  2.82  2.63   2.77       2.77  32516800           False
# 1  735968.0  2.77  2.80  2.64   2.75       2.75  12972300           False
# 2  735969.0  2.66  2.71  2.47   2.51       2.51  23759400           False
# 3  735970.0  2.43  2.48  2.26   2.28       2.28  22203500           False
# 4  735971.0  2.36  2.42  2.10   2.14       2.14  31822400           False

# %%
from mplfinance.original_flavor import candlestick_ohlc

fig = plt.figure(figsize=(14,10))
ax = plt.subplot(2, 1, 1)
candlestick_ohlc(ax,dfc.values, width=0.5, colorup='g', colordown='r', alpha=1.0)
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
ax.grid(True, which='both')
ax.minorticks_on()
axv = ax.twinx()
colors = dfc.VolumePositive.map({True: 'g', False: 'r'})
axv.bar(dfc.Date, dfc['Volume'], color=colors, alpha=0.4)
axv.axes.yaxis.set_ticklabels([])
axv.set_ylim(0, 3*df.Volume.max())
ax.set_title('Stock '+ symbol +' Closing Price')
ax.set_ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
in_neck = talib.CDLINNECK(df['Open'], df['High'], df['Low'], df['Close'])

in_neck = in_neck[in_neck != 0]

# %%
df['in_neck'] = talib.CDLINNECK(df['Open'], df['High'], df['Low'], df['Close'])

# %%
df.loc[df['in_neck'] !=0]
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2017-03-27  13.350000  13.780000  13.210000  13.700000  13.700000  42686800
# 2017-04-11  13.020000  13.290000  12.710000  13.100000  13.100000  59916600
# 2021-05-04  77.949997  78.669998  77.040001  78.610001  78.610001  59194300
#
#             in_neck
# Date
# 2017-03-27     -100
# 2017-04-11     -100
# 2021-05-04     -100

# %%
df['Adj Close'].loc[df['in_neck'] !=0]
# Out:
# Date
# 2017-03-27    13.700000
# 2017-04-11    13.100000
# 2021-05-04    78.610001
# Name: Adj Close, dtype: float64

# %%
df['Adj Close'].loc[df['in_neck'] !=0].index
# Out:
# DatetimeIndex(['2017-03-27', '2017-04-11', '2021-05-04'], dtype='datetime64[ns]', name='Date', freq=None)

# %%
in_neck
# Out:
# Date
# 2017-03-27   -100
# 2017-04-11   -100
# 2021-05-04   -100
# dtype: int32

# %%
in_neck.index
# Out:
# DatetimeIndex(['2017-03-27', '2017-04-11', '2021-05-04'], dtype='datetime64[ns]', name='Date', freq=None)

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-01-04    2.770000    2.820000    2.630000    2.770000    2.770000
# 2016-01-05    2.770000    2.800000    2.640000    2.750000    2.750000
# 2016-01-06    2.660000    2.710000    2.470000    2.510000    2.510000
# 2016-01-07    2.430000    2.480000    2.260000    2.280000    2.280000
# 2016-01-08    2.360000    2.420000    2.100000    2.140000    2.140000
# ...                ...         ...         ...         ...         ...
# 2021-10-01  102.599998  103.000000  100.639999  102.449997  102.449997
# 2021-10-04  101.739998  101.849998   99.820000  100.339996  100.339996
# 2021-10-05  100.919998  102.870003  100.610001  101.809998  101.809998
# 2021-10-06  100.449997  103.720001  100.349998  103.639999  103.639999
# 2021-10-07  104.599998  107.949997  104.459999  106.449997  106.449997
#
#               Volume  in_neck
# Date
# 2016-01-04  32516800        0
# 2016-01-05  12972300        0
# ...

# %%
fig = plt.figure(figsize=(20,16))
ax = plt.subplot(2, 1, 1)
candlestick_ohlc(ax,dfc.values, width=0.5, colorup='g', colordown='r', alpha=1.0)
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
ax.grid(True, which='both')
ax.minorticks_on()
axv = ax.twinx()
ax.plot_date(df['Adj Close'].loc[df['in_neck'] !=0].index, df['Adj Close'].loc[df['in_neck'] !=0],
                'Dc', # marker style 'o', color 'g'
                fillstyle='none', # circle is not filled (with color)
                ms=10.0) 
colors = dfc.VolumePositive.map({True: 'g', False: 'r'})
axv.bar(dfc.Date, dfc['Volume'], color=colors, alpha=0.4)
axv.axes.yaxis.set_ticklabels([])
axv.set_ylim(0, 3*df.Volume.max())
ax.set_title('Stock '+ symbol +' Closing Price')
ax.set_ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# ## Plot Certain dates

# %%
df = df['2021-05-01':'2021-06-01']
dfc = df.copy()
dfc['VolumePositive'] = dfc['Open'] < dfc['Adj Close']
#dfc = dfc.dropna()
dfc = dfc.reset_index()
dfc['Date'] = pd.to_datetime(dfc['Date'])
dfc['Date'] = dfc['Date'].apply(mdates.date2num)
dfc.head()
# Out:
#        Date       Open       High        Low      Close  Adj Close    Volume  \
# 0  737913.0  81.970001  82.000000  78.459999  78.550003  78.550003  66323300
# 1  737914.0  77.949997  78.669998  77.040001  78.610001  78.610001  59194300
# 2  737915.0  79.050003  79.300003  77.360001  77.830002  77.830002  42310200
# 3  737916.0  77.629997  78.059998  76.470001  77.889999  77.889999  38661300
# 4  737917.0  78.750000  79.570000  78.220001  78.809998  78.809998  36954200
#
#    in_neck  VolumePositive
# 0        0           False
# 1     -100            True
# 2        0           False
# 3        0            True
# 4        0            True

# %%
fig = plt.figure(figsize=(20,16))
ax = plt.subplot(2, 1, 1)
ax.set_facecolor('navajowhite')
candlestick_ohlc(ax,dfc.values, width=0.5, colorup='burlywood', colordown='red', alpha=1.0)
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
#ax.grid(True, which='both')
#ax.minorticks_on()
axv = ax.twinx()
ax.plot_date(df['Adj Close'].loc[df['in_neck'] !=0].index, df['Adj Close'].loc[df['in_neck'] !=0],
                'ok', # marker style 'o', color 'g'
                fillstyle='none', # circle is not filled (with color)
                ms=25.0) 
colors = dfc.VolumePositive.map({True: 'burlywood', False: 'red'})
axv.bar(dfc.Date, dfc['Volume'], color=colors, alpha=0.4)
axv.axes.yaxis.set_ticklabels([])
axv.set_ylim(0, 3*df.Volume.max())
ax.set_title('Stock '+ symbol +' Closing Price')
ax.set_ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# # Highlight Candlestick

# %%
from matplotlib.dates import date2num
from datetime import datetime

fig = plt.figure(figsize=(20,16))
ax = plt.subplot(2, 1, 1)
candlestick_ohlc(ax,dfc.values, width=0.5, colorup='g', colordown='r', alpha=1.0)
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
#ax.grid(True, which='both')
#ax.minorticks_on()
axv = ax.twinx()
ax.axvspan(date2num(datetime(2021,5,3)), date2num(datetime(2021,5,5)), 
           label="In-Neck Bearish",color="red", alpha=0.3)
ax.legend()
colors = dfc.VolumePositive.map({True: 'g', False: 'r'})
axv.bar(dfc.Date, dfc['Volume'], color=colors, alpha=0.4)
axv.axes.yaxis.set_ticklabels([])
axv.set_ylim(0, 3*df.Volume.max())
ax.set_title('Stock '+ symbol +' Closing Price')
ax.set_ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')
