# %% [markdown]
# # Candlestick Three Inside Up/Down

# %% [markdown]
# https://www.investopedia.com/terms/t/three-inside-updown.asp

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import talib

import warnings
warnings.filterwarnings("ignore")

# yahoo finance is used to fetch data 
import yfinance as yf
yf.pdr_override()

# %%
# input
symbol = 'GME'
start = '2020-01-01'
end = '2021-10-08'

# Read data 
df = yf.download(symbol,start,end)

# View Columns
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#             Open  High   Low  Close  Adj Close   Volume
# Date
# 2020-01-02  6.14  6.47  6.07   6.31       6.31  4453600
# 2020-01-03  6.21  6.25  5.84   5.88       5.88  3543900
# 2020-01-06  5.80  5.91  5.60   5.85       5.85  3394800
# 2020-01-07  5.77  5.83  5.44   5.52       5.52  5228000
# 2020-01-08  5.49  5.85  5.41   5.72       5.72  5629400

# %% [markdown]
# ## Candlestick with Three Inside Up/Down

# %%
from matplotlib import dates as mdates
import datetime as dt

dfc = df.copy()
dfc['VolumePositive'] = dfc['Open'] < dfc['Adj Close']
#dfc = dfc.dropna()
dfc = dfc.reset_index()
dfc['Date'] = pd.to_datetime(dfc['Date'])
dfc['Date'] = dfc['Date'].apply(mdates.date2num)
dfc.head()
# Out:
#        Date  Open  High   Low  Close  Adj Close   Volume  VolumePositive
# 0  737426.0  6.14  6.47  6.07   6.31       6.31  4453600            True
# 1  737427.0  6.21  6.25  5.84   5.88       5.88  3543900           False
# 2  737430.0  5.80  5.91  5.60   5.85       5.85  3394800            True
# 3  737431.0  5.77  5.83  5.44   5.52       5.52  5228000           False
# 4  737432.0  5.49  5.85  5.41   5.72       5.72  5629400            True

# %%
from mplfinance.original_flavor import candlestick_ohlc

fig = plt.figure(figsize=(14,10))
ax = plt.subplot(2, 1, 1)
candlestick_ohlc(ax,dfc.values, width=0.5, colorup='g', colordown='r', alpha=1.0)
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
ax.grid(True, which='both')
ax.minorticks_on()
axv = ax.twinx()
colors = dfc.VolumePositive.map({True: 'g', False: 'r'})
axv.bar(dfc.Date, dfc['Volume'], color=colors, alpha=0.4)
axv.axes.yaxis.set_ticklabels([])
axv.set_ylim(0, 3*df.Volume.max())
ax.set_title('Stock '+ symbol +' Closing Price')
ax.set_ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
three_inside = talib.CDL3INSIDE(df['Open'], df['High'], df['Low'], df['Close'])

three_inside = three_inside[three_inside != 0]

# %%
df['three_inside'] = talib.CDL3INSIDE(df['Open'], df['High'], df['Low'], df['Close'])

# %%
df.loc[df['three_inside'] !=0]
# Out:
#                   Open    High         Low       Close   Adj Close    Volume  \
# Date
# 2020-03-05    3.700000    3.99    3.590000    3.960000    3.960000   3599400
# 2020-05-27    4.570000    4.71    4.360000    4.690000    4.690000   3146600
# 2020-08-26    4.970000    5.22    4.920000    5.110000    5.110000   2779700
# 2020-10-08    9.540000   13.64    9.190000   13.490000   13.490000  76453600
# 2020-11-06   11.520000   12.17   11.320000   11.860000   11.860000   5518200
# 2020-12-14   13.340000   13.43   12.140000   12.720000   12.720000  10007100
# 2021-06-04  256.019989  265.00  245.770004  248.360001  248.360001   3637500
#
#             three_inside
# Date
# 2020-03-05           100
# 2020-05-27           100
# 2020-08-26           100
# 2020-10-08           100
# 2020-11-06           100
# 2020-12-14          -100
# 2021-06-04          -100

# %%
df['Adj Close'].loc[df['three_inside'] !=0]
# Out:
# Date
# 2020-03-05      3.960000
# 2020-05-27      4.690000
# 2020-08-26      5.110000
# 2020-10-08     13.490000
# 2020-11-06     11.860000
# 2020-12-14     12.720000
# 2021-06-04    248.360001
# Name: Adj Close, dtype: float64

# %%
df['Adj Close'].loc[df['three_inside'] !=0].index
# Out:
# DatetimeIndex(['2020-03-05', '2020-05-27', '2020-08-26', '2020-10-08',
#                '2020-11-06', '2020-12-14', '2021-06-04'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
three_inside
# Out:
# Date
# 2020-03-05    100
# 2020-05-27    100
# 2020-08-26    100
# 2020-10-08    100
# 2020-11-06    100
# 2020-12-14   -100
# 2021-06-04   -100
# dtype: int32

# %%
three_inside.index
# Out:
# DatetimeIndex(['2020-03-05', '2020-05-27', '2020-08-26', '2020-10-08',
#                '2020-11-06', '2020-12-14', '2021-06-04'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-02    6.140000    6.470000    6.070000    6.310000    6.310000
# 2020-01-03    6.210000    6.250000    5.840000    5.880000    5.880000
# 2020-01-06    5.800000    5.910000    5.600000    5.850000    5.850000
# 2020-01-07    5.770000    5.830000    5.440000    5.520000    5.520000
# 2020-01-08    5.490000    5.850000    5.410000    5.720000    5.720000
# ...                ...         ...         ...         ...         ...
# 2021-10-01  179.399994  179.490005  172.250000  176.910004  176.910004
# 2021-10-04  175.949997  176.949997  170.770004  171.360001  171.360001
# 2021-10-05  171.190002  173.169998  166.699997  172.179993  172.179993
# 2021-10-06  170.059998  172.960007  165.809998  171.070007  171.070007
# 2021-10-07  172.000000  175.199997  170.539993  172.119995  172.119995
#
#              Volume  three_inside
# Date
# 2020-01-02  4453600             0
# ...

# %%
fig = plt.figure(figsize=(20,16))
ax = plt.subplot(2, 1, 1)
candlestick_ohlc(ax,dfc.values, width=0.5, colorup='g', colordown='r', alpha=1.0)
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
ax.grid(True, which='both')
ax.minorticks_on()
axv = ax.twinx()
ax.plot_date(df['Adj Close'].loc[df['three_inside'] !=0].index, df['Adj Close'].loc[df['three_inside'] !=0],
                'Dc', # marker style 'o', color 'g'
                fillstyle='none', # circle is not filled (with color)
                ms=10.0) 
colors = dfc.VolumePositive.map({True: 'g', False: 'r'})
axv.bar(dfc.Date, dfc['Volume'], color=colors, alpha=0.4)
axv.axes.yaxis.set_ticklabels([])
axv.set_ylim(0, 3*df.Volume.max())
ax.set_title('Stock '+ symbol +' Closing Price')
ax.set_ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# ## Plot Certain dates

# %%
df = df['2020-03-01':'2020-12-31']
dfc = df.copy()
dfc['VolumePositive'] = dfc['Open'] < dfc['Adj Close']
#dfc = dfc.dropna()
dfc = dfc.reset_index()
dfc['Date'] = pd.to_datetime(dfc['Date'])
dfc['Date'] = dfc['Date'].apply(mdates.date2num)
dfc.head()
# Out:
#        Date  Open  High   Low  Close  Adj Close   Volume  three_inside  \
# 0  737486.0  3.60  3.85  3.39   3.83       3.83  3208400             0
# 1  737487.0  3.88  3.89  3.50   3.63       3.63  4282500             0
# 2  737488.0  3.71  3.83  3.46   3.77       3.77  4257600             0
# 3  737489.0  3.70  3.99  3.59   3.96       3.96  3599400           100
# 4  737490.0  3.84  4.07  3.76   3.92       3.92  2096800             0
#
#    VolumePositive
# 0            True
# 1           False
# 2            True
# 3            True
# 4            True

# %%
fig = plt.figure(figsize=(20,16))
ax = plt.subplot(2, 1, 1)
ax.set_facecolor('black')
candlestick_ohlc(ax,dfc.values, width=0.5, colorup='g', colordown='r', alpha=1.0)
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
#ax.grid(True, which='both')
#ax.minorticks_on()
axv = ax.twinx()
ax.plot_date(df['Adj Close'].loc[df['three_inside'] !=0].index, df['Adj Close'].loc[df['three_inside'] !=0],
                'vy', # marker style 'o', color 'g'
                fillstyle='none', # circle is not filled (with color)
                ms=30.0) 
colors = dfc.VolumePositive.map({True: 'g', False: 'r'})
axv.bar(dfc.Date, dfc['Volume'], color=colors, alpha=0.4)
axv.axes.yaxis.set_ticklabels([])
axv.set_ylim(0, 3*df.Volume.max())
ax.set_title('Stock '+ symbol +' Closing Price')
ax.set_ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# # Highlight Candlestick

# %%
from matplotlib.dates import date2num
from datetime import datetime

fig = plt.figure(figsize=(20,16))
ax = plt.subplot(2, 1, 1)
candlestick_ohlc(ax,dfc.values, width=0.5, colorup='g', colordown='r', alpha=1.0)
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
#ax.grid(True, which='both')
#ax.minorticks_on()
axv = ax.twinx()
ax.axvspan(date2num(datetime(2020,3,5)), date2num(datetime(2020,3,9)), 
           label="Three Inside Up/Down",color="green", alpha=0.3)
ax.axvspan(date2num(datetime(2020,12,14)), date2num(datetime(2020,12,17)), 
           label="Three Inside Up/Down",color="red", alpha=0.3)
ax.legend()
colors = dfc.VolumePositive.map({True: 'g', False: 'r'})
axv.bar(dfc.Date, dfc['Volume'], color=colors, alpha=0.4)
axv.axes.yaxis.set_ticklabels([])
axv.set_ylim(0, 3*df.Volume.max())
ax.set_title('Stock '+ symbol +' Closing Price')
ax.set_ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')
