# %% [markdown]
# # Candlestick Morning Star

# %% [markdown]
# https://www.investopedia.com/terms/m/morningstar.asp

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import talib

import warnings
warnings.filterwarnings("ignore")

# yahoo finance is used to fetch data 
import yfinance as yf
yf.pdr_override()

# %%
# input
symbol = 'AMD'
start = '2018-01-01'
end = '2020-01-01'

# Read data 
df = yf.download(symbol,start,end)

# View Columns
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#              Open   High    Low  Close  Adj Close     Volume
# Date
# 2018-01-02  10.42  11.02  10.34  10.98      10.98   44146300
# 2018-01-03  11.61  12.14  11.36  11.55      11.55  154066700
# 2018-01-04  12.10  12.43  11.97  12.12      12.12  109503000
# 2018-01-05  12.19  12.22  11.66  11.88      11.88   63808900
# 2018-01-08  12.01  12.30  11.85  12.28      12.28   63346000

# %% [markdown]
# ## Candlestick with Morning Star

# %%
from matplotlib import dates as mdates
import datetime as dt

dfc = df.copy()
dfc['VolumePositive'] = dfc['Open'] < dfc['Adj Close']
#dfc = dfc.dropna()
dfc = dfc.reset_index()
dfc['Date'] = pd.to_datetime(dfc['Date'])
dfc['Date'] = dfc['Date'].apply(mdates.date2num)
dfc.head()
# Out:
#        Date   Open   High    Low  Close  Adj Close     Volume  VolumePositive
# 0  736696.0  10.42  11.02  10.34  10.98      10.98   44146300            True
# 1  736697.0  11.61  12.14  11.36  11.55      11.55  154066700           False
# 2  736698.0  12.10  12.43  11.97  12.12      12.12  109503000            True
# 3  736699.0  12.19  12.22  11.66  11.88      11.88   63808900           False
# 4  736702.0  12.01  12.30  11.85  12.28      12.28   63346000            True

# %%
from mplfinance.original_flavor import candlestick_ohlc

fig = plt.figure(figsize=(14,10))
ax = plt.subplot(2, 1, 1)
candlestick_ohlc(ax,dfc.values, width=0.5, colorup='g', colordown='r', alpha=1.0)
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
ax.grid(True, which='both')
ax.minorticks_on()
axv = ax.twinx()
colors = dfc.VolumePositive.map({True: 'g', False: 'r'})
axv.bar(dfc.Date, dfc['Volume'], color=colors, alpha=0.4)
axv.axes.yaxis.set_ticklabels([])
axv.set_ylim(0, 3*df.Volume.max())
ax.set_title('Stock '+ symbol +' Closing Price')
ax.set_ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
morning_star = talib.CDLMORNINGSTAR(df['Open'], df['High'], df['Low'], df['Close'])

morning_star = morning_star[morning_star != 0]

# %%
df['morning_star'] = talib.CDLMORNINGSTAR(df['Open'], df['High'], df['Low'], df['Close'])

# %%
df.loc[df['morning_star'] !=0]
# Out:
#                  Open   High        Low  Close  Adj Close     Volume  \
# Date
# 2018-08-13  19.160000  19.93  19.120001  19.73      19.73   81411300
# 2018-12-26  16.879999  17.91  16.030001  17.90      17.90  108811800
#
#             morning_star
# Date
# 2018-08-13           100
# 2018-12-26           100

# %%
df['Adj Close'].loc[df['morning_star'] !=0]
# Out:
# Date
# 2018-08-13    19.73
# 2018-12-26    17.90
# Name: Adj Close, dtype: float64

# %%
df['Adj Close'].loc[df['morning_star'] !=0].index
# Out:
# DatetimeIndex(['2018-08-13', '2018-12-26'], dtype='datetime64[ns]', name='Date', freq=None)

# %%
morning_star
# Out:
# Date
# 2018-08-13    100
# 2018-12-26    100
# dtype: int32

# %%
morning_star.index
# Out:
# DatetimeIndex(['2018-08-13', '2018-12-26'], dtype='datetime64[ns]', name='Date', freq=None)

# %%
df
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2018-01-02  10.420000  11.020000  10.340000  10.980000  10.980000   44146300
# 2018-01-03  11.610000  12.140000  11.360000  11.550000  11.550000  154066700
# 2018-01-04  12.100000  12.430000  11.970000  12.120000  12.120000  109503000
# 2018-01-05  12.190000  12.220000  11.660000  11.880000  11.880000   63808900
# 2018-01-08  12.010000  12.300000  11.850000  12.280000  12.280000   63346000
# ...               ...        ...        ...        ...        ...        ...
# 2019-12-24  46.099998  46.610001  45.770000  46.540001  46.540001   44432200
# 2019-12-26  46.990002  47.310001  45.660000  46.630001  46.630001   57562800
# 2019-12-27  46.849998  46.880001  45.980000  46.180000  46.180000   36581300
# 2019-12-30  46.139999  46.169998  44.660000  45.520000  45.520000   41149700
# 2019-12-31  45.070000  46.090000  44.919998  45.860001  45.860001   31673200
#
#             morning_star
# Date
# ...

# %%
fig = plt.figure(figsize=(20,16))
ax = plt.subplot(2, 1, 1)
candlestick_ohlc(ax,dfc.values, width=0.5, colorup='g', colordown='r', alpha=1.0)
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
ax.grid(True, which='both')
ax.minorticks_on()
axv = ax.twinx()
ax.plot_date(df['Adj Close'].loc[df['morning_star'] !=0].index, df['Adj Close'].loc[df['morning_star'] !=0],
                'ob', # marker style 'o', color 'g'
                fillstyle='none', # circle is not filled (with color)
                ms=10.0) 
colors = dfc.VolumePositive.map({True: 'g', False: 'r'})
axv.bar(dfc.Date, dfc['Volume'], color=colors, alpha=0.4)
axv.axes.yaxis.set_ticklabels([])
axv.set_ylim(0, 3*df.Volume.max())
ax.set_title('Stock '+ symbol +' Closing Price')
ax.set_ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# ## Plot Certain dates

# %%
df = df['2018-08-01':'2018-12-31']
dfc = df.copy()
dfc['VolumePositive'] = dfc['Open'] < dfc['Adj Close']
#dfc = dfc.dropna()
dfc = dfc.reset_index()
dfc['Date'] = pd.to_datetime(dfc['Date'])
dfc['Date'] = dfc['Date'].apply(mdates.date2num)
dfc.head()
# Out:
#        Date       Open       High        Low      Close  Adj Close    Volume  \
# 0  736907.0  18.340000  18.950001  18.320000  18.480000  18.480000  75495200
# 1  736908.0  18.170000  18.830000  18.000000  18.790001  18.790001  52867100
# 2  736909.0  18.940001  19.059999  18.370001  18.490000  18.490000  53232100
# 3  736912.0  18.889999  19.440001  18.459999  19.430000  19.430000  83579700
# 4  736913.0  19.530001  19.709999  19.080000  19.559999  19.559999  72822600
#
#    morning_star  VolumePositive
# 0             0            True
# 1             0            True
# 2             0           False
# 3             0            True
# 4             0            True

# %%
fig = plt.figure(figsize=(20,16))
ax = plt.subplot(2, 1, 1)
candlestick_ohlc(ax,dfc.values, width=0.5, colorup='g', colordown='r', alpha=1.0)
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
ax.grid(True, which='both')
ax.minorticks_on()
axv = ax.twinx()
ax.plot_date(df['Adj Close'].loc[df['morning_star'] !=0].index, df['Adj Close'].loc[df['morning_star'] !=0],
                'ob', # marker style 'o', color 'g'
                fillstyle='none', # circle is not filled (with color)
                ms=30.0) 
colors = dfc.VolumePositive.map({True: 'g', False: 'r'})
axv.bar(dfc.Date, dfc['Volume'], color=colors, alpha=0.4)
axv.axes.yaxis.set_ticklabels([])
axv.set_ylim(0, 3*df.Volume.max())
ax.set_title('Stock '+ symbol +' Closing Price')
ax.set_ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')
