# %% [markdown]
# # Big Three Trading Strategy

# %% [markdown]
# 20 Period Simple Moving Average
#
# 40 Period Simple Moving Average
#
# 80 Period Simple Moving Average
#
#
# https://tradingstrategyguides.com/big-three-trading-strategy/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# fix_yahoo_finance is used to fetch data 
import fix_yahoo_finance as yf
yf.pdr_override()

# %%
# input
symbol = 'AAPL'
start = '2014-01-01'
end = '2018-12-31'

# Read data 
df = yf.download(symbol,start,end)

# View Columns
df.head()
# Out:
# [*********************100%***********************]  1 of 1 downloaded
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2014-01-02  79.382858  79.575714  78.860001  79.018570  66.964325   58671200
# 2014-01-03  78.980003  79.099998  77.204285  77.282860  65.493416   98116900
# 2014-01-06  76.778572  78.114288  76.228569  77.704285  65.850533  103152700
# 2014-01-07  77.760002  77.994286  76.845711  77.148575  65.379593   79302300
# 2014-01-08  76.972855  77.937141  76.955711  77.637146  65.793633   64632400

# %%
df['SMA_20'] = df['Adj Close'].rolling(20).mean()
df['SMA_40'] = df['Adj Close'].rolling(40).mean()
df['SMA_80'] = df['Adj Close'].rolling(80).mean()

# %%
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-12-24  148.149994  151.550003  146.589996  146.830002  146.202972
# 2018-12-26  148.300003  157.229996  146.720001  157.169998  156.498810
# 2018-12-27  155.839996  156.770004  150.070007  156.149994  155.483154
# 2018-12-28  157.500000  158.520004  154.550003  156.229996  155.562820
# 2018-12-31  158.529999  159.360001  156.479996  157.740005  157.066376
#
#               Volume      SMA_20      SMA_40      SMA_80
# Date
# 2018-12-24  37169200  168.362927  183.308669  201.930087
# 2018-12-26  58582500  167.494154  181.855454  201.095198
# 2018-12-27  53117100  166.593516  180.477562  200.215365
# 2018-12-28  42291400  165.363292  179.075367  199.327473
# 2018-12-31  35003500  164.277449  177.572836  198.476857

# %%
fig, ax = plt.subplots(figsize=(16,9))

ax.plot(df.index, df['Adj Close'], label='Price')
ax.plot(df.index, df['SMA_20'], label = '20-days SMA')
ax.plot(df.index, df['SMA_40'], label = '40-days SMA')
ax.plot(df.index, df['SMA_80'], label = '80-days SMA')

ax.legend(loc='best')
ax.set_ylabel('Price')
ax.set_title('Big Three Trading Strategy')
# Out:
# Text(0.5,1,'Big Three Trading Strategy')

# %% [markdown]
# ## Closer View
#
# plot different dates

# %%
new_dates = df['2017-01-01':'2018-12-31']
new_dates.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-01-03  115.800003  116.330002  114.760002  116.150002  112.140007
# 2017-01-04  115.849998  116.510002  115.750000  116.019997  112.014503
# 2017-01-05  115.919998  116.860001  115.809998  116.610001  112.584129
# 2017-01-06  116.779999  118.160004  116.470001  117.910004  113.839249
# 2017-01-09  117.949997  119.430000  117.940002  118.989998  114.881950
#
#               Volume      SMA_20      SMA_40      SMA_80
# Date
# 2017-01-03  28781900  110.923994  108.556407  108.972593
# 2017-01-04  21118100  111.257566  108.729710  109.134513
# 2017-01-05  22193600  111.579069  108.879359  109.275817
# 2017-01-06  31751900  111.911193  109.044697  109.402674
# 2017-01-09  33561900  112.242833  109.240447  109.496698

# %%
plt.figure(figsize=(16,10))
plt.plot(new_dates['Adj Close'], label='Price')
plt.plot(new_dates['SMA_20'], label = '20-days SMA')
plt.plot(new_dates['SMA_40'], label = '40-days SMA')
plt.plot(new_dates['SMA_80'], label = '80-days SMA')
plt.legend(loc='best')
plt.grid(True)
plt.ylabel('Price')
plt.xlabel('Dates')
plt.title('Big Three Trading Strategy')
# Out:
# Text(0.5,1,'Big Three Trading Strategy')

# %%
plt.figure(figsize=(16,10))
plt.plot_date(x=new_dates.index ,y=new_dates['Adj Close'], label='Price')
plt.plot(new_dates['SMA_20'], label = '20-days SMA')
plt.plot(new_dates['SMA_40'], label = '40-days SMA')
plt.plot(new_dates['SMA_80'], label = '80-days SMA')
plt.legend(loc='best')
plt.grid(True)
plt.ylabel('Price')
plt.xlabel('Dates')
plt.title('Big Three Trading Strategy')
# Out:
# Text(0.5,1,'Big Three Trading Strategy')

# %%
plt.figure(figsize=(16,10))
plt.plot_date(x=new_dates.index ,y=new_dates['Adj Close'], fmt='r-', label='Price')
plt.plot(new_dates['SMA_20'], label = '20-days SMA', color='b')
plt.plot(new_dates['SMA_40'], label = '40-days SMA', color='y')
plt.plot(new_dates['SMA_80'], label = '80-days SMA', color='green')
plt.legend(loc='best')
plt.grid(True)
plt.ylabel('Price')
plt.xlabel('Date')
plt.title('Big Three Trading Strategy')
# Out:
# Text(0.5,1,'Big Three Trading Strategy')
